# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# here, we begin by importing some important libraries!

# %%
#load the dataset
df=pd.read_csv('Diwali Sales Data.csv',encoding = "ISO-8859-1")

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop the columns
df.drop(columns=['Status','unnamed1'],inplace=True)

# %%
#find the shape of data 
df.shape
# Out:
# (11251, 13)

# %%
#find null values
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
#drop null values
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
#drop nullvalues
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (11251, 13)

# %%
#change the datatype
df['Amount']=df['Amount'].astype(int)

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# ***Exploratory Data Analysis***
#
# **gender**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax=sns.countplot(x='Gender', data=df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_gender= df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values (by='Amount', ascending=False)
sns.barplot(x='Gender', y='Amount', data= sales_gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# **Conclusion= Most of the buyers are females who have more purchasing power than males**

# %% [markdown]
# ***Evaluate according to Age***

# %%
ax=sns.countplot(x='Age Group', data=df, hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#total amount vs age_group 

sales_age= df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values (by='Amount', ascending=False)
sns.barplot(x='Age Group', y='Amount', data= sales_age)
# Out:
# <AxesSubplot:xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# **conlcusion:- The above evaluation says that most of the buyers are females who fall in 26-35 years of age group.**

# %% [markdown]
# **State**

# %%
#total number orders from top 10 states
sales_state= df.groupby(['State'],as_index=False)['Orders'].sum().sort_values (by='Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot(x='State', y='Orders', data= sales_state)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Orders'>

# %%
#total number of orders from 10 states 
sales_state= df.groupby(['State'],as_index=False)['Amount'].sum().sort_values (by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})

sns.barplot(x='State', y='Amount', data= sales_state)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Amount'>

# %% [markdown]
# **Conclusion:- It says that most of the orders were from Uttar Pradesh, Maharashtra, Karnataka, and amount were from Uttar Pradesh, Karnatka, and then, Maharashtra**

# %% [markdown]
# **Marital Status**

# %%
 #evaluate according to maritial status 
ax =sns.countplot(x='Marital_Status', data=df)
sns.set(rc={'figure.figsize':(7,3)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status','Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(7,5)})

sns.barplot( data = sales_state, x='Marital_Status', y='Amount', hue='Gender')
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# **conclusion:- With this we can conclude that most of the shoppers are married (females)**

# %% [markdown]
# **Occupation**

# %%
#evaluate according to occupation 
ax =sns.countplot(x='Occupation', data=df)
sns.set(rc={'figure.figsize':(25,7)})
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# **This colcludes that most of the buyers are from IT Sector, Aviation, and Healthcare**

# %% [markdown]
# **Category of Product**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#evaluate according to occupation 
ax =sns.countplot(x='Product_Category', data=df)
sns.set(rc={'figure.figsize':(25,7)})
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# **This colcludes that most of the ordered product categories include clothing & apparel, food and electronics. **

# %%
sales_state = df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(25,5)})

sns.barplot( data = sales_state, x='Product_Category', y='Amount',)
# Out:
# <AxesSubplot:xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# This colcludes that most of the sold product categories include food, clothing & apparel,  and electronics. *

# %%
sales_state = df.groupby(['Product_ID'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})

sns.barplot( data = sales_state, x='Product_ID', y='Amount',)
# Out:
# <AxesSubplot:xlabel='Product_ID', ylabel='Amount'>

# %% [markdown]
# This colcludes that most of the sold products are P00265242, P00110942, P00184942

# %% [markdown]
# ****FINAL CONLCUSION :
# The whole analysis conlcudes that married femalesin age group 26-35 years from states Uttar Pradesh, Maharashtra, and Karnatka, working at IT, Aviation and Healthcare are more likely to buy products from Food, Clothings & Electronics category with most sold products  P00265242, P00110942, P00184942.****
